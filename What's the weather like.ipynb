# %% [markdown]
# # What's the Weather Like?

# %% [markdown]
# ## Analysis
# #### Observed Trend 1: It is hotter at the equator; however, the northern hemisphere is currently warmer than the southern hemisphere
#
# #### Observed Trend 2: The northern hemisphere appears to have some of the coldest temperatures as well which may be due in part to a higher concentration. More cities with greater temperature diversity.
#
# #### Observed Trend 3: Humidity, Cloudiness, and Wind Speed are uniform across the northern and southern hemispheres. Humidity is high, wind is low and cloudiness is evenly dispersed across the board.

# %%
# Dependencies

from citipy import citipy
import seaborn
import pandas as pd
import numpy as np
import requests as req
import json
import random
import time
import matplotlib.pyplot as plt
import datetime
import csv
import os

# %%
# Save config information.
#api_key = "25bc90a1196e6f153eece0bc0b0fc9eb" #Amed's key
api_key = "924783bda048569443e49dd6a03e5591"
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial" #Fahrenheit

# %% [markdown]
# # Generate Cities List

# %%
# grab random coordinates an find the closest cities
sample_size = 500

coordinates = [((random.randint(-90, 90)),(random.randint(-180, 180))) for _ in range (sample_size)]

city_list = []

cities = []
for coordinate_pair in coordinates:
    lat, lon = coordinate_pair
    cities.append(citipy.nearest_city(lat, lon))
    city_names = citipy.nearest_city(lat, lon).city_name

#create a list of random cities    
    city_list.append(city_names)

#city_list

# %% [markdown]
# # Perform API Calls

# %%
# Build partial query URL
query_url = url + "appid=" + api_key + "&units=" + units + "&q="

# List for holding the latitude and temperature

city_data = []
cloudiness_data = []
country_data = []
date_data = []
humidity_data = []
lat_data = []
lon_data = []
max_temp_data = []
wind_speed_data = []

counter = 0

#clear/ prep csv file for query log
output_path = os.path.join("Weather_Query_log")
with open(output_path, 'w', newline='') as csvfile:
            csvwriter = csv.writer(csvfile, delimiter=',')

for city in city_list:
    
    try:
        print("----------------------")
        print("Now logging city # " + str(counter))
        print(query_url + city)
        response = req.get(query_url + city).json()
        
        # Specify the file to write to
        output_path = os.path.join("Weather_Query_log")

        # Open the file using "write" mode. Specify the variable to hold the contents
        with open(output_path, 'a', newline='') as csvfile:

            # Initialize csv.writer
            csvwriter = csv.writer(csvfile, delimiter=',')

            # Write the first row (column headers)
            csvwriter.writerow(['----------------------'])
            csvwriter.writerow(["Now logging city # " + str(counter)])
            csvwriter.writerow([query_url + city]) 

            
        city_data.append(response.get("name"))
        cloudiness_data.append(response.get("clouds").get("all"))
        country_data.append(response.get("sys").get("country"))
        date_data.append(response.get("dt"))
        humidity_data.append(response.get("main").get("humidity"))
        lat_data.append(response.get("coord").get("lat"))
        lon_data.append(response.get("coord").get("lon"))
        max_temp_data.append(response.get("main").get("temp_max"))
        wind_speed_data.append(response.get("wind").get("speed"))

        counter = counter + 1
        if counter % 59 == 0:
            time.sleep(60)
    except:
        print("Skipping this...")

weather_data = {"City" : city_data,
                "Cloudiness": cloudiness_data,
                "Country": country_data,
                "Date": date_data,
                "Humidity": humidity_data,
                "Lat": lat_data,
                "Lng": lon_data,
                "Max Temp": max_temp_data,
                "Wind Speed": wind_speed_data,
                }

weather_data = pd.DataFrame(weather_data)

date_stamp = str(weather_data.iloc[0,3])

date_stamp = datetime.datetime.fromtimestamp(int(date_stamp)).strftime('%m-%d-%Y')

weather_data.count()
# Out:
# ----------------------
# Now logging city # 0
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=jamestown
# ----------------------
# Now logging city # 1
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=bredasdorp
# ----------------------
# Now logging city # 2
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=busselton
# ----------------------
# Now logging city # 3
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=jiwani
# ----------------------
# Now logging city # 4
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=ushuaia
# ----------------------
# Now logging city # 5
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=hithadhoo
# ----------------------
# Now logging city # 6
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=rikitea
# ----------------------
# Now logging city # 7
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=tuktoyaktuk
# ----------------------
# Now logging city # 8
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=hithadhoo
# ----------------------
# Now logging city # 9
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=rikitea
# ----------------------
# Now logging city # 10
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=alice
# ----------------------
# Now logging city # 11
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=bluff
# ----------------------
# Now logging city # 12
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=kamenskoye
# ----------------------
# Now logging city # 13
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=gurgan
# ----------------------
# Now logging city # 14
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=ushuaia
# ----------------------
# Now logging city # 15
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=butaritari
# ----------------------
# Now logging city # 16
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=punta arenas
# ----------------------
# Now logging city # 17
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=cidreira
# ----------------------
# Now logging city # 18
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=nueva loja
# ----------------------
# Now logging city # 19
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=loukhi
# ----------------------
# Now logging city # 20
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=port alfred
# ----------------------
# Now logging city # 21
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=svetlyy
# ----------------------
# Now logging city # 22
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=marcona
# ----------------------
# Now logging city # 23
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=new norfolk
# ----------------------
# Now logging city # 24
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=yellowknife
# ----------------------
# Now logging city # 25
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=yellowknife
# ----------------------
# Now logging city # 26
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=georgetown
# ----------------------
# Now logging city # 27
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=fukue
# ----------------------
# Now logging city # 28
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=rikitea
# ----------------------
# Now logging city # 29
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=bafoulabe
# ----------------------
# Now logging city # 30
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=kutum
# ----------------------
# Now logging city # 31
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=bluff
# ----------------------
# Now logging city # 32
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=hermanus
# ----------------------
# Now logging city # 33
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=taolanaro
# ----------------------
# Now logging city # 34
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=solhan
# ----------------------
# Now logging city # 35
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=upernavik
# ----------------------
# Now logging city # 36
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=punta arenas
# ----------------------
# Now logging city # 37
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=arraial do cabo
# ----------------------
# Now logging city # 38
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=rikitea
# ----------------------
# Now logging city # 39
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=avarua
# ----------------------
# Now logging city # 40
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=yellowknife
# ----------------------
# Now logging city # 41
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=rockingham
# ----------------------
# Now logging city # 42
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=vaini
# ----------------------
# Now logging city # 43
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=shahrud
# ----------------------
# Now logging city # 44
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=rudsar
# ----------------------
# Now logging city # 45
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=tongren
# ----------------------
# Now logging city # 46
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=port blair
# ----------------------
# Now logging city # 47
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=cidreira
# ----------------------
# Now logging city # 48
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=alice springs
# ----------------------
# Now logging city # 49
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=hilo
# ----------------------
# Now logging city # 50
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=alice springs
# ----------------------
# Now logging city # 51
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=toliary
# ----------------------
# Now logging city # 52
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=taolanaro
# ----------------------
# Now logging city # 53
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=hilo
# ----------------------
# Now logging city # 54
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=dingle
# ----------------------
# Now logging city # 55
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=subtanjalla
# ----------------------
# Now logging city # 56
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=hermanus
# ----------------------
# Now logging city # 57
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=albany
# ----------------------
# Now logging city # 58
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=avarua
# ----------------------
# Now logging city # 59
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=hobart
# ----------------------
# Now logging city # 60
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=porto santo
# ----------------------
# Now logging city # 61
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=ribeira grande
# ----------------------
# Now logging city # 62
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=mataura
# ----------------------
# Now logging city # 63
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=kerki
# ----------------------
# Now logging city # 64
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=erdenet
# ----------------------
# Now logging city # 65
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=san cristobal
# ----------------------
# Now logging city # 66
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=esperance
# ----------------------
# Now logging city # 67
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=illoqqortoormiut
# ----------------------
# Now logging city # 68
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=sabha
# ----------------------
# Now logging city # 69
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=gornja koprivna
# ----------------------
# Now logging city # 70
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=punta arenas
# ----------------------
# Now logging city # 71
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=ushuaia
# ----------------------
# Now logging city # 72
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=punta arenas
# ----------------------
# Now logging city # 73
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=torbay
# ----------------------
# Now logging city # 74
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=tessalit
# ----------------------
# Now logging city # 75
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=north bend
# ----------------------
# Now logging city # 76
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=shache
# ----------------------
# Now logging city # 77
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=bluff
# ----------------------
# Now logging city # 78
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=mount gambier
# ----------------------
# Now logging city # 79
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=klaksvik
# ----------------------
# Now logging city # 80
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=rikitea
# ----------------------
# Now logging city # 81
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=oktyabrskoye
# ----------------------
# Now logging city # 82
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=suhbaatar
# ----------------------
# Now logging city # 83
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=busselton
# ----------------------
# Now logging city # 84
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=vao
# ----------------------
# Now logging city # 85
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=aban
# ----------------------
# Now logging city # 86
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=sambava
# ----------------------
# Now logging city # 87
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=beira
# ----------------------
# Now logging city # 88
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=bilibino
# ----------------------
# Now logging city # 89
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=albany
# ----------------------
# Now logging city # 90
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=cherskiy
# ----------------------
# Now logging city # 91
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=mayo
# ----------------------
# Now logging city # 92
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=phalaborwa
# ----------------------
# Now logging city # 93
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=sao filipe
# ----------------------
# Now logging city # 94
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=katsuura
# ----------------------
# Now logging city # 95
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=haines junction
# ----------------------
# Now logging city # 96
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=cape town
# ----------------------
# Now logging city # 97
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=sao joao da barra
# ----------------------
# Now logging city # 98
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=tasiilaq
# ----------------------
# Now logging city # 99
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=geraldton
# ----------------------
# Now logging city # 100
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=aklavik
# ----------------------
# Now logging city # 101
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=arraial do cabo
# ----------------------
# Now logging city # 102
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=florida
# ----------------------
# Now logging city # 103
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=upernavik
# ----------------------
# Now logging city # 104
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=norman wells
# ----------------------
# Now logging city # 105
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=garden city
# ----------------------
# Now logging city # 106
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=bengkulu
# ----------------------
# Now logging city # 107
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=amderma
# ----------------------
# Now logging city # 108
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=vaini
# ----------------------
# Now logging city # 109
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=san borja
# ----------------------
# Now logging city # 110
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=georgetown
# ----------------------
# Now logging city # 111
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=mataura
# ----------------------
# Now logging city # 112
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=saint george
# ----------------------
# Now logging city # 113
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=iqaluit
# ----------------------
# Now logging city # 114
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=yellowknife
# ----------------------
# Now logging city # 115
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=xudat
# ----------------------
# Now logging city # 116
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=vaini
# ----------------------
# Now logging city # 117
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=taolanaro
# ----------------------
# Now logging city # 118
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=azar shahr
# ----------------------
# Now logging city # 119
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=albany
# ----------------------
# Now logging city # 120
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=fort nelson
# ----------------------
# Now logging city # 121
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=killini
# ----------------------
# Now logging city # 122
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=oyama
# ----------------------
# Now logging city # 123
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=mataura
# ----------------------
# Now logging city # 124
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=fuxin
# ----------------------
# Now logging city # 125
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=punta arenas
# ----------------------
# Now logging city # 126
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=punta arenas
# ----------------------
# Now logging city # 127
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=rikitea
# ----------------------
# Now logging city # 128
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=vaini
# ----------------------
# Now logging city # 129
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=barentsburg
# ----------------------
# Now logging city # 130
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=rikitea
# ----------------------
# Now logging city # 131
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=thoen
# ----------------------
# Now logging city # 132
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=esperance
# ----------------------
# Now logging city # 133
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=cape town
# ----------------------
# Now logging city # 134
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=sayanskiy
# ----------------------
# Now logging city # 135
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=atuona
# ----------------------
# Now logging city # 136
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=mataura
# ----------------------
# Now logging city # 137
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=busselton
# ----------------------
# Now logging city # 138
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=kavaratti
# ----------------------
# Now logging city # 139
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=mataura
# ----------------------
# Now logging city # 140
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=atuona
# ----------------------
# Now logging city # 141
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=mahebourg
# ----------------------
# Now logging city # 142
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=zhirnovsk
# ----------------------
# Now logging city # 143
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=zhigansk
# ----------------------
# Now logging city # 144
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=kenai
# ----------------------
# Now logging city # 145
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=chabahar
# ----------------------
# Now logging city # 146
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=kapaa
# ----------------------
# Now logging city # 147
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=lebu
# ----------------------
# Now logging city # 148
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=punta arenas
# ----------------------
# Now logging city # 149
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=qandala
# ----------------------
# Now logging city # 150
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=palmer
# ----------------------
# Now logging city # 151
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=unguia
# ----------------------
# Now logging city # 152
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=high level
# ----------------------
# Now logging city # 153
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=tsihombe
# ----------------------
# Now logging city # 154
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=jamestown
# ----------------------
# Now logging city # 155
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=busselton
# ----------------------
# Now logging city # 156
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=saint-joseph
# ----------------------
# Now logging city # 157
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=saskylakh
# ----------------------
# Now logging city # 158
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=atambua
# ----------------------
# Now logging city # 159
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=leningradskiy
# ----------------------
# Now logging city # 160
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=kikwit
# ----------------------
# Now logging city # 161
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=arlit
# ----------------------
# Now logging city # 162
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=thompson
# ----------------------
# Now logging city # 163
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=huaicheng
# ----------------------
# Now logging city # 164
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=port elizabeth
# ----------------------
# Now logging city # 165
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=albany
# ----------------------
# Now logging city # 166
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=comodoro rivadavia
# ----------------------
# Now logging city # 167
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=milingimbi
# ----------------------
# Now logging city # 168
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=kargat
# ----------------------
# Now logging city # 169
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=punta arenas
# ----------------------
# Now logging city # 170
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=hohhot
# ----------------------
# Now logging city # 171
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=riverton
# ----------------------
# Now logging city # 172
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=castro
# ----------------------
# Now logging city # 173
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=luderitz
# ----------------------
# Now logging city # 174
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=ushuaia
# ----------------------
# Now logging city # 175
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=hamilton
# ----------------------
# Now logging city # 176
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=ponta do sol
# ----------------------
# Now logging city # 177
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=sambava
# ----------------------
# Now logging city # 178
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=auka
# ----------------------
# Now logging city # 179
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=manaus
# ----------------------
# Now logging city # 180
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=taolanaro
# ----------------------
# Now logging city # 181
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=atuona
# ----------------------
# Now logging city # 182
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=bacolod
# ----------------------
# Now logging city # 183
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=fort nelson
# ----------------------
# Now logging city # 184
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=severo-kurilsk
# ----------------------
# Now logging city # 185
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=ushuaia
# ----------------------
# Now logging city # 186
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=albany
# ----------------------
# Now logging city # 187
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=the valley
# ----------------------
# Now logging city # 188
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=albany
# ----------------------
# Now logging city # 189
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=norman wells
# ----------------------
# Now logging city # 190
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=ushuaia
# ----------------------
# Now logging city # 191
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=roebourne
# ----------------------
# Now logging city # 192
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=vaini
# ----------------------
# Now logging city # 193
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=illoqqortoormiut
# ----------------------
# Now logging city # 194
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=qaanaaq
# ----------------------
# Now logging city # 195
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=punta arenas
# ----------------------
# Now logging city # 196
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=tsihombe
# ----------------------
# Now logging city # 197
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=cherskiy
# ----------------------
# Now logging city # 198
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=te anau
# ----------------------
# Now logging city # 199
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=belushya guba
# ----------------------
# Now logging city # 200
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=kapaa
# ----------------------
# Now logging city # 201
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=avarua
# ----------------------
# Now logging city # 202
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=bluff
# ----------------------
# Now logging city # 203
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=amderma
# ----------------------
# Now logging city # 204
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=korla
# ----------------------
# Now logging city # 205
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=sri aman
# ----------------------
# Now logging city # 206
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=pevek
# ----------------------
# Now logging city # 207
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=broome
# ----------------------
# Now logging city # 208
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=leningradskiy
# ----------------------
# Now logging city # 209
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=ushuaia
# ----------------------
# Now logging city # 210
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=hasaki
# ----------------------
# Now logging city # 211
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=kawhia
# ----------------------
# Now logging city # 212
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=mount gambier
# ----------------------
# Now logging city # 213
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=taolanaro
# ----------------------
# Now logging city # 214
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=koupela
# ----------------------
# Now logging city # 215
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=nouadhibou
# ----------------------
# Now logging city # 216
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=rikitea
# ----------------------
# Now logging city # 217
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=codrington
# ----------------------
# Now logging city # 218
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=coahuayana
# ----------------------
# Now logging city # 219
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=east london
# ----------------------
# Now logging city # 220
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=ust-kuyga
# ----------------------
# Now logging city # 221
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=banda aceh
# ----------------------
# Now logging city # 222
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=ushuaia
# ----------------------
# Now logging city # 223
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=pacific grove
# ----------------------
# Now logging city # 224
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=albany
# ----------------------
# Now logging city # 225
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=castro
# ----------------------
# Now logging city # 226
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=baiyin
# ----------------------
# Now logging city # 227
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=bethel
# ----------------------
# Now logging city # 228
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=mataura
# ----------------------
# Now logging city # 229
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=ushuaia
# ----------------------
# Now logging city # 230
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=ahipara
# ----------------------
# Now logging city # 231
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=tuktoyaktuk
# ----------------------
# Now logging city # 232
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=kungurtug
# ----------------------
# Now logging city # 233
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=iqaluit
# ----------------------
# Now logging city # 234
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=mana
# ----------------------
# Now logging city # 235
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=port elizabeth
# ----------------------
# Now logging city # 236
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=albany
# ----------------------
# Now logging city # 237
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=bluff
# ----------------------
# Now logging city # 238
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=airai
# ----------------------
# Now logging city # 239
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=avarua
# ----------------------
# Now logging city # 240
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=rikitea
# ----------------------
# Now logging city # 241
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=bulungu
# ----------------------
# Now logging city # 242
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=lavrentiya
# ----------------------
# Now logging city # 243
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=dzhusaly
# ----------------------
# Now logging city # 244
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=borovoy
# ----------------------
# Now logging city # 245
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=micheweni
# ----------------------
# Now logging city # 246
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=provideniya
# ----------------------
# Now logging city # 247
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=salalah
# ----------------------
# Now logging city # 248
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=huarmey
# ----------------------
# Now logging city # 249
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=bredasdorp
# ----------------------
# Now logging city # 250
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=hithadhoo
# ----------------------
# Now logging city # 251
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=ancud
# ----------------------
# Now logging city # 252
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=fukue
# ----------------------
# Now logging city # 253
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=tuktoyaktuk
# ----------------------
# Now logging city # 254
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=busselton
# ----------------------
# Now logging city # 255
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=airai
# ----------------------
# Now logging city # 256
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=puerto ayora
# ----------------------
# Now logging city # 257
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=tikrit
# ----------------------
# Now logging city # 258
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=mar del plata
# ----------------------
# Now logging city # 259
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=cherepanovo
# ----------------------
# Now logging city # 260
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=aklavik
# ----------------------
# Now logging city # 261
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=kirakira
# ----------------------
# Now logging city # 262
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=mersing
# ----------------------
# Now logging city # 263
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=mayo
# ----------------------
# Now logging city # 264
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=gallup
# ----------------------
# Now logging city # 265
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=port elizabeth
# ----------------------
# Now logging city # 266
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=mahebourg
# ----------------------
# Now logging city # 267
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=awjilah
# ----------------------
# Now logging city # 268
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=leningradskiy
# ----------------------
# Now logging city # 269
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=hasaki
# ----------------------
# Now logging city # 270
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=mataura
# ----------------------
# Now logging city # 271
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=avarua
# ----------------------
# Now logging city # 272
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=taolanaro
# ----------------------
# Now logging city # 273
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=chokurdakh
# ----------------------
# Now logging city # 274
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=punta arenas
# ----------------------
# Now logging city # 275
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=bluff
# ----------------------
# Now logging city # 276
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=taolanaro
# ----------------------
# Now logging city # 277
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=illoqqortoormiut
# ----------------------
# Now logging city # 278
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=lebu
# ----------------------
# Now logging city # 279
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=saleaula
# ----------------------
# Now logging city # 280
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=upernavik
# ----------------------
# Now logging city # 281
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=new norfolk
# ----------------------
# Now logging city # 282
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=petropavlovsk-kamchatskiy
# ----------------------
# Now logging city # 283
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=belushya guba
# ----------------------
# Now logging city # 284
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=torbay
# ----------------------
# Now logging city # 285
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=raga
# ----------------------
# Now logging city # 286
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=ancud
# ----------------------
# Now logging city # 287
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=katsuura
# ----------------------
# Now logging city # 288
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=cockburn town
# ----------------------
# Now logging city # 289
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=jalu
# ----------------------
# Now logging city # 290
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=chuy
# ----------------------
# Now logging city # 291
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=bayangol
# ----------------------
# Now logging city # 292
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=hithadhoo
# ----------------------
# Now logging city # 293
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=mataura
# ----------------------
# Now logging city # 294
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=belushya guba
# ----------------------
# Now logging city # 295
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=ibra
# ----------------------
# Now logging city # 296
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=la palma
# ----------------------
# Now logging city # 297
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=betanzos
# ----------------------
# Now logging city # 298
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=ushuaia
# ----------------------
# Now logging city # 299
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=hamilton
# ----------------------
# Now logging city # 300
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=waingapu
# ----------------------
# Now logging city # 301
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=shilong
# ----------------------
# Now logging city # 302
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=tuatapere
# ----------------------
# Now logging city # 303
# ...
# ----------------------
# Now logging city # 400
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=rikitea
# ----------------------
# Now logging city # 401
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=bouca
# ----------------------
# Now logging city # 402
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=kapaa
# ----------------------
# Now logging city # 403
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=malatya
# ----------------------
# Now logging city # 404
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=khromtau
# ----------------------
# Now logging city # 405
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=hithadhoo
# ----------------------
# Now logging city # 406
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=east london
# ----------------------
# Now logging city # 407
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=talnakh
# ----------------------
# Now logging city # 408
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=cape town
# ----------------------
# Now logging city # 409
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=kodiak
# ----------------------
# Now logging city # 410
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=kamogawa
# ----------------------
# Now logging city # 411
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=vostok
# ----------------------
# Now logging city # 412
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=mar del plata
# ----------------------
# Now logging city # 413
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=albany
# ----------------------
# Now logging city # 414
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=hermanus
# ----------------------
# Now logging city # 415
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=mataura
# ----------------------
# Now logging city # 416
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=asau
# ----------------------
# Now logging city # 417
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=rikitea
# ----------------------
# Now logging city # 418
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=barentsburg
# ----------------------
# Now logging city # 419
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=talnakh
# ----------------------
# Now logging city # 420
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=mar del plata
# ----------------------
# Now logging city # 421
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=attawapiskat
# ----------------------
# Now logging city # 422
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=karamay
# ----------------------
# Now logging city # 423
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=filadelfia
# ----------------------
# Now logging city # 424
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=port elizabeth
# ----------------------
# Now logging city # 425
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=hasaki
# ----------------------
# Now logging city # 426
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=port elizabeth
# ----------------------
# Now logging city # 427
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=garissa
# ----------------------
# Now logging city # 428
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=aginskoye
# ----------------------
# Now logging city # 429
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=bluff
# ----------------------
# Now logging city # 430
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=caravelas
# ----------------------
# Now logging city # 431
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=punta arenas
# ----------------------
# Now logging city # 432
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=illoqqortoormiut
# ----------------------
# Now logging city # 433
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=kavaratti
# ----------------------
# Now logging city # 434
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=tasiilaq
# ----------------------
# Now logging city # 435
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=katsuura
# ----------------------
# Now logging city # 436
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=saint-philippe
# ----------------------
# Now logging city # 437
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=atuona
# ----------------------
# Now logging city # 438
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=gardner
# ----------------------
# Now logging city # 439
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=dzhusaly
# ----------------------
# Now logging city # 440
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=nazare
# ----------------------
# Now logging city # 441
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=guerrero negro
# ----------------------
# Now logging city # 442
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=hobart
# ----------------------
# Now logging city # 443
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=qaanaaq
# ----------------------
# Now logging city # 444
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=boa vista
# ----------------------
# Now logging city # 445
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=cape town
# ----------------------
# Now logging city # 446
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=kanigoro
# ----------------------
# Now logging city # 447
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=punta arenas
# ----------------------
# Now logging city # 448
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=thompson
# ----------------------
# Now logging city # 449
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=hermanus
# ----------------------
# Now logging city # 450
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=bethel
# ----------------------
# Now logging city # 451
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=atuona
# ----------------------
# Now logging city # 452
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=new norfolk
# ----------------------
# Now logging city # 453
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=mys shmidta
# ----------------------
# Now logging city # 454
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=awbari
# ----------------------
# Now logging city # 455
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=hermanus
# ----------------------
# Now logging city # 456
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=vaini
# ----------------------
# Now logging city # 457
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=rikitea
# ----------------------
# Now logging city # 458
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=hovd
# ----------------------
# Now logging city # 459
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=rosarito
# ----------------------
# Now logging city # 460
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=taolanaro
# ----------------------
# Now logging city # 461
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=attawapiskat
# ----------------------
# Now logging city # 462
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=taolanaro
# ----------------------
# Now logging city # 463
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=vaini
# ----------------------
# Now logging city # 464
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=tura
# ----------------------
# Now logging city # 465
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=chuy
# ----------------------
# Now logging city # 466
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=ushuaia
# ----------------------
# Now logging city # 467
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=albany
# ----------------------
# Now logging city # 468
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=rebrikha
# ----------------------
# Now logging city # 469
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=bilibino
# ----------------------
# Now logging city # 470
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=rocha
# ----------------------
# Now logging city # 471
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=tasiilaq
# ----------------------
# Now logging city # 472
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=ostrovnoy
# ----------------------
# Now logging city # 473
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=kuytun
# ----------------------
# Now logging city # 474
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=rikitea
# ----------------------
# Now logging city # 475
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=ushuaia
# ----------------------
# Now logging city # 476
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=necochea
# ----------------------
# Now logging city # 477
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=carnarvon
# ----------------------
# Now logging city # 478
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=ushuaia
# ----------------------
# Now logging city # 479
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=cape town
# ----------------------
# Now logging city # 480
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=cape town
# ----------------------
# Now logging city # 481
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=parrita
# ----------------------
# Now logging city # 482
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=los andes
# ----------------------
# Now logging city # 483
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=avarua
# ----------------------
# Now logging city # 484
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=kruisfontein
# ----------------------
# Now logging city # 485
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=tautira
# ----------------------
# Now logging city # 486
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=naze
# ----------------------
# Now logging city # 487
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=bagdarin
# ----------------------
# Now logging city # 488
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=marcona
# ----------------------
# Now logging city # 489
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=faya
# ----------------------
# Now logging city # 490
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=port macquarie
# ----------------------
# Now logging city # 491
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=bredasdorp
# ----------------------
# Now logging city # 492
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=vaini
# ----------------------
# Now logging city # 493
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=jiddah
# ----------------------
# Now logging city # 494
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=teya
# ----------------------
# Now logging city # 495
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=chokurdakh
# ----------------------
# Now logging city # 496
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=ushuaia
# ----------------------
# Now logging city # 497
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=arrifes
# ----------------------
# Now logging city # 498
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=pelym
# ----------------------
# Now logging city # 499
# http://api.openweathermap.org/data/2.5/weather?appid=924783bda048569443e49dd6a03e5591&units=imperial&q=vesoul
# City          500
# Cloudiness    500
# Country       500
# Date          500
# Humidity      500
# Lat           500
# Lng           500
# Max Temp      500
# Wind Speed    500
# dtype: int64

# %%
weather_data.to_csv('weather_data.csv')

weather_data.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0   Jamestown          90      US  1509152160        50  42.10  -79.24
# 1  Bredasdorp           0      ZA  1509152400        76 -34.53   20.04
# 2   Busselton           8      AU  1509153705       100 -33.65  115.33
# 3      Jiwani           0      PK  1509153706        96  25.05   61.74
# 4     Ushuaia          20      AR  1509148800        70 -54.80  -68.30
#
#    Max Temp  Wind Speed
# 0     57.20       11.41
# 1     50.00        5.82
# 2     63.94       24.94
# 3     68.21        2.75
# 4     46.40        8.05

# %% [markdown]
# # Latitude vs Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature" + " " + date_stamp)
plt.ylabel("Max Temperature F")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("City Latitude vs. Max Temperature.png")

# Show plot
plt.show()

# %% [markdown]
# # Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity Plot" + " " + date_stamp)
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("City Latitude vs. Humidity Plot.png")

# Show plot
plt.show()

# %% [markdown]
# # Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for atitude vs. Cloudiness
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness" + " " + date_stamp)
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("City Latitude vs. Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# # Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for Latitude vs. Wind Speed
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed" + " " + date_stamp)
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("City Latitude vs. Wind Speed.png")

# Show plot
plt.show()

# %% [markdown]
# # Data Source Map

# %%
# Build a scatter plot for Latitude vs. Wind Speed
plt.scatter(weather_data["Lng"], weather_data["Lat"], marker="o")

# Incorporate the other graph properties
plt.title("Data Source Map" + " " + date_stamp)
plt.ylabel("Latitude")
plt.xlabel("Longitude")
plt.grid(True)

# Save the figure
plt.savefig("Data Source Map.png")

# Show plot
plt.show()
